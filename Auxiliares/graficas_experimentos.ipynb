# %%
from google.colab import drive
drive.mount('/content/drive')

workdir = '/content/drive/MyDrive/dataset_ml/amazon_men_actualizado/'
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# ...

# %%
def readFile(fileName):
        fileObj = open(fileName, "r") #opens the file in read mode
        words = fileObj.read().splitlines() #puts the file into an array
        fileObj.close()
        return words

# %% [markdown]
# # MEN

# %% [markdown]
# dimensiones latentes en BPR= [10,20,35,50,75,100]
#
# dimensiones latentes en VBPR=[(10,200),(20,200),(10,500),(20,500)]
#
# auc: 0.7383658500450674
# 0.7262252698147869
# 0.7609324908907982
# 0.7518993901796848

# %% [markdown]
# Resultados:
#
# **BPR (10 min):** 0.7449294615491121
#
# **VBPR (15 min):** 0.7642327263041068
#
# **IRGAN (50 min):**
#
# load model...
# gen  0.667684160360828
# dis  0.49914048726409244
#
# D train: 0.7531651924661317 D test:
# 0.6808382445633901
#
#
# G train:
# 0.574513821295674 G test: 0.7939860665610609
#
#
#
# **VIRGAN normal (15-10d-5g) argmax:**
#
# load model... gen 0.9116949460266968 dis 0.49850717191236965 (3 epocas)
#
# G train:0.8918364826814386 G test: 0.7962727415096519
#
# **VIRGAN normal argmax boots (inicializacion) :**
#
# load model...gen  0.9112476453708832 dis  0.5031011486266249 (3 nº interacciones, 10 min)
#
# test: 0.7924462936669415
#
# G train: 0.9280702236824342 G test: 0.8085925214610905 (1 h)
#
#
# no sirve considerar todos ni tomar el top algo sobre una muestra mas grande en la inicilizacion´
#
#
#
# **VIRGAN (15-1-1) argmax boots (inicializacion) :**
#
# misma inicializacion.
#
#
# D train: 0.6598641704925843 D test: 0.5801180858592949
#
# G train: 0.9198166097131708 G test: 0.8090884325775983 (18 min)
#
#
# más rápido esta ténica y funciona casi igual
#
#
#
# **V&T IRGAN (2-1-1) argmax boots (inicializacion) :**
#
# load model...
# gen  0.8837447040840262
# dis  0.5011702181114173 (1h)
#
# test: 0.8243988336222555
#
#
# D train: 0.5756609965568795 D test: 0.5158881399868004
#
# G train: 0.8806364252583635 G test:0.8302309605734084 (2 h)

# %%
import pandas as pd
df= pd.DataFrame(columns=["Modelo", "Diferencia de AUC", "Conjunto"])

df.loc[0]= ["VIb*", 0.9198- 0.9112, "Train" ]
df.loc[1]= ["VIb*", 0.8089- 0.7924, "Test" ]
df.loc[2]= ["VTIb*",0.8806- 0.8837, "Train" ]
df.loc[3]= ["VTIb*", 0.8302- 0.8243, "Test"]

# %%
import plotly.express as px
fig = px.bar(df, x="Modelo", y="Diferencia de AUC",
             color='Conjunto', barmode='group',
             height=500,width=600)
fig.update_layout(title_text='Generalización de la metodología adversaria c/r a la inicialización'
    )

newnames = {'Conjunto=Train':'Train', 'Conjunto=Test': 'Test'}
fig.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                      legendgroup = newnames[t.name],
                                      hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])
                                     )
                  )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="13be912f-2ef2-4910-8e50-76a35eb6161b" class="plotly-graph-div" style="height:500px; width:600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("
))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6f7eaf6f-2908-43dd-9b1a-c3b113cf21c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6f7eaf6f-2908-43dd-9b1a-c3b113cf21c4")) {
#                     Plotly.newPlot(
#                         '6f7eaf6f-2908-43dd-9b1a-c3b113cf21c4',
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure()

# Add traces
fig.add_trace(go.Scatter(x=list(range(15)), y=acus_d,
                    mode='lines',
                    name='Discriminador'))
fig.add_trace(go.Scatter(x=list(range(15)), y=aucs_g,
                    mode='lines',
                    name='Generador'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5b212e4b-c165-4cb3-9e92-0b3dc03c2988" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5b212e4b-c165-4cb3-9e92-0b3dc03c2988")) {
#                     Plotly.newPlot(
#                         '5b212e4b-c165-4cb3-9e92-0b3dc03c2988',
# ...

# %% [markdown]
# Siguiendo el framework desarrollado por [IRGAN] para recomendación adversaria basada en filtrado colaborativo, en este trabajo se extendió dicho modelos para incluir im

# %% [markdown]
# # Women

# %% [markdown]
# auc malla vbpr

# %%
acus_malla_vbpr_men=[0.7383658500450674,
0.7262252698147869,
0.7609324908907982,
0.7518993901796848]

acus_malla_vbpr_women=[0.7664654818726434,
0.7802065905155017,
0.807568026172142,
0.7997140124907808]

# %%
import plotly.graph_objects as go
fig = go.Figure()

# Add traces
fig.add_trace(go.Scatter(x=["(10,200)","(20,200)","(10,500)","(20,500)"], y=acus_malla_vbpr_men,
                    mode='lines+markers',name='Men'))
fig.add_trace(go.Scatter(x=["(10,200)","(20,200)","(10,500)","(20,500)"], y=acus_malla_vbpr_women,
                    mode='lines+markers',name='Women'))

fig.update_layout(   height=500,width=700,  title="Selección de dimensionalidad de los embeddings",
    xaxis_title="Representación latente de filtrado colaborativo y lantente visual",
    yaxis_title="AUC en train",
    #legend_title="Data Set",
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="60a13cc8-f999-4b7f-b8dd-65ca0b3537ea" class="plotly-graph-div" style="height:500px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("60a13cc8-f999-4b7f-b8dd-65ca0b3537ea")) {
#                     Plotly.newPlot(
#                         '60a13cc8-f999-4b7f-b8dd-65ca0b3537ea',
# ...

# %%
import pandas as pd
df= pd.DataFrame(columns=["Modelo", "Diferencia de AUC", "Conjunto"])

df.loc[0]= ["VIb*", 0.7889865269004773 - 0.8153143939135364 , "Train" ]
df.loc[1]= ["VIb*", 0.8062087304815215 - 0.8020417637172242 , "Test" ]
df.loc[2]= ["VTIb*", 0.8631263960844127-0.8935948956597833, "Train" ]
df.loc[3]= ["VTIb*",0.8708085340134709 - 0.8666143202968859 , "Test"]

# %%
import plotly.express as px
fig = px.bar(df, x="Modelo", y="Diferencia de AUC",
             color='Conjunto', barmode='group',
             height=500,width=600)
fig.update_layout(title_text='Generalización de la metodología adversaria c/r a la inicialización'
    )

newnames = {'Conjunto=Train':'Train', 'Conjunto=Test': 'Test'}
fig.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                      legendgroup = newnames[t.name],
                                      hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])
                                     )
                  )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="588b4f4d-a992-4e2b-8ddd-384023bf7a33" class="plotly-graph-div" style="height:500px; width:600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("588b4f4d-a992-4e2b-8ddd-384023bf7a33")) {
#                     Plotly.newPlot(
#                         '588b4f4d-a992-4e2b-8ddd-384023bf7a33',
# ...

# %% [markdown]
# grafica de irgan original para women
